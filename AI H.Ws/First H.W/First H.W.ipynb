# %%
import pandas as pd

# %%
fa = pd.read_csv("Games.csv")

# %%
fa.head()
# Out:
#          Console                                        GameName  \
# 0             PC             Baldur's Gate 3 Early Access Review
# 1             NS  Control: Ultimate Edition Cloud Version Review
# 2  XONE, PC, PS4    Doom Eternal: The Ancient Gods Part 1 Review
# 3  XONE, PC, PS4                       Watch Dogs: Legion Review
# 4             PC                             Ring Of Pain Review
#
#          Review  Score
# 0  Early Access      6
# 1          Good      7
# 2          Good      7
# 3         Great      8
# 4         Great      8

# %%
fa.tail()
# Out:
#       Console                                           GameName    Review  \
# 14796      PC                                     Doom II Review     Great
# 14797      PC  Dungeon Master II: The Legend of Skullkeep Review  Mediocre
# 14798      PC                                    Endorfun Review      Good
# 14799      PC                              FIFA Soccer 96 Review    Superb
# 14800      PC                               Full Throttle Review     Great
#
#        Score
# 14796      8
# 14797      5
# 14798      7
# 14799      9
# 14800      8

# %%
fa
# Out:
#              Console                                           GameName  \
# 0                 PC                Baldur's Gate 3 Early Access Review
# 1                 NS     Control: Ultimate Edition Cloud Version Review
# 2      XONE, PC, PS4       Doom Eternal: The Ancient Gods Part 1 Review
# 3      XONE, PC, PS4                          Watch Dogs: Legion Review
# 4                 PC                                Ring Of Pain Review
# ...              ...                                                ...
# 14796             PC                                     Doom II Review
# 14797             PC  Dungeon Master II: The Legend of Skullkeep Review
# 14798             PC                                    Endorfun Review
# 14799             PC                              FIFA Soccer 96 Review
# 14800             PC                               Full Throttle Review
#
#              Review  Score
# 0      Early Access      6
# 1              Good      7
# ...

# %%
fa.shape
# Out:
# (14801, 4)

# %%
fa.describe()
# Out:
#               Score
# count  14801.000000
# mean       6.429498
# std        1.611753
# min        1.000000
# 25%        6.000000
# 50%        7.000000
# 75%        8.000000
# max        9.000000

# %%
fa[['GameName']]
# Out:
#                                                 GameName
# 0                    Baldur's Gate 3 Early Access Review
# 1         Control: Ultimate Edition Cloud Version Review
# 2           Doom Eternal: The Ancient Gods Part 1 Review
# 3                              Watch Dogs: Legion Review
# 4                                    Ring Of Pain Review
# ...                                                  ...
# 14796                                     Doom II Review
# 14797  Dungeon Master II: The Legend of Skullkeep Review
# 14798                                    Endorfun Review
# 14799                              FIFA Soccer 96 Review
# 14800                               Full Throttle Review
#
# [14801 rows x 1 columns]

# %%
fa["GameName"].value_counts()
# Out:
# GameName
# Madden NFL 06 Review                  9
# Ratatouille Review                    9
# Madden NFL 08 Review                  9
# Surf's Up Review                      9
# Open Season Review                    9
#                                      ..
# Baseball Mogul 2009 Review            1
# Golf: Tee It Up Review                1
# Schizoid Review                       1
# Wonder World Amusement Park Review    1
# Full Throttle Review                  1
# Name: count, Length: 11256, dtype: int64

# %%
fa["GameName"].unique()
# Out:
# array(["Baldur's Gate 3 Early Access Review",
#        'Control: Ultimate Edition Cloud Version Review',
#        'Doom Eternal: The Ancient Gods Part 1 Review', ...,
#        'Endorfun Review', 'FIFA Soccer 96 Review', 'Full Throttle Review'],
#       dtype=object)

# %%
len(fa["GameName"].unique())
# Out:
# 11256

# %%
fa[fa['Score']<= 30]
# Out:
#              Console                                           GameName  \
# 0                 PC                Baldur's Gate 3 Early Access Review
# 1                 NS     Control: Ultimate Edition Cloud Version Review
# 2      XONE, PC, PS4       Doom Eternal: The Ancient Gods Part 1 Review
# 3      XONE, PC, PS4                          Watch Dogs: Legion Review
# 4                 PC                                Ring Of Pain Review
# ...              ...                                                ...
# 14796             PC                                     Doom II Review
# 14797             PC  Dungeon Master II: The Legend of Skullkeep Review
# 14798             PC                                    Endorfun Review
# 14799             PC                              FIFA Soccer 96 Review
# 14800             PC                               Full Throttle Review
#
#              Review  Score
# 0      Early Access      6
# 1              Good      7
# ...

# %%
fa[["Console","GameName"]][fa['Score']<= 30]
# Out:
#              Console                                           GameName
# 0                 PC                Baldur's Gate 3 Early Access Review
# 1                 NS     Control: Ultimate Edition Cloud Version Review
# 2      XONE, PC, PS4       Doom Eternal: The Ancient Gods Part 1 Review
# 3      XONE, PC, PS4                          Watch Dogs: Legion Review
# 4                 PC                                Ring Of Pain Review
# ...              ...                                                ...
# 14796             PC                                     Doom II Review
# 14797             PC  Dungeon Master II: The Legend of Skullkeep Review
# 14798             PC                                    Endorfun Review
# 14799             PC                              FIFA Soccer 96 Review
# 14800             PC                               Full Throttle Review
#
# [14801 rows x 2 columns]

# %%
fa[(fa['Score']<= 30) | (fa['Score']>= 192)]
# Out:
#              Console                                           GameName  \
# 0                 PC                Baldur's Gate 3 Early Access Review
# 1                 NS     Control: Ultimate Edition Cloud Version Review
# 2      XONE, PC, PS4       Doom Eternal: The Ancient Gods Part 1 Review
# 3      XONE, PC, PS4                          Watch Dogs: Legion Review
# 4                 PC                                Ring Of Pain Review
# ...              ...                                                ...
# 14796             PC                                     Doom II Review
# 14797             PC  Dungeon Master II: The Legend of Skullkeep Review
# 14798             PC                                    Endorfun Review
# 14799             PC                              FIFA Soccer 96 Review
# 14800             PC                               Full Throttle Review
#
#              Review  Score
# 0      Early Access      6
# 1              Good      7
# ...

# %%
fa.sort_values('Score',ascending=False)
# Out:
#                  Console                                GameName   Review  \
# 12947                 PS                         NHL 2000 Review   Superb
# 13383                 PC            Myth II: Soulblighter Review   Superb
# 678              PS4, PC                          F1 2017 Review   Superb
# 680            XONE, PS4                    Madden NFL 18 Review   Superb
# 684    PC, PS4, NS, XONE                          Thumper Review   Superb
# ...                  ...                                     ...      ...
# 12479                 DC                  Spirit of Speed Review  Abysmal
# 11068                 PC                         Mistmare Review  Abysmal
# 11932                PS2  Gravity Games: Street Vert Dirt Review  Abysmal
# 14256                GBC                     Yoda Stories Review  Abysmal
# 5863                  DS                  Deal or No Deal Review  Abysmal
#
#        Score
# 12947      9
# 13383      9
# 678        9
# 680        9
# ...

# %%
a = fa[(fa['Score']<= 30) | (fa['Score']>= 192)]

# %%
a.to_csv("Games2.csv",index=False)

# %%
fa.iloc[20:36,0:2]
# Out:
#               Console                                           GameName
# 20          XONE, PS4    Crash Bandicoot 4 Review – Platformer's Delight
# 21                 NS        Kirby Fighters 2 Review – 2 Kirby 2 Furious
# 22                 PC                 Pendragon Review – Endless Legends
# 23                 PC        Serious Sam 4 Review – The Fourth Encounter
# 24                PS4                 NBA 2K21 Review – Ball Another Day
# 25                 PC           Crusader Kings 3 Review – Pass the Duchy
# 26                PS4          Spelunky 2 Review –  Snakes On A 2D Plane
# 27                 PC  Mafia: Definitive Edition Review – An Offer Yo...
# 28                 PC  Surgeon Simulator 2 Review – Surgical Imprecision
# 29             PC, NS     Hades Review – The Long, Hard Road Out of Hell
# 30                PS4  13 Sentinels: Aegis Rim Review – Wow, Cool Robot!
# 31                 NS  Super Mario 3D All-Stars Review – Shoot For Th...
# ...

# %%
a
# Out:
#              Console                                           GameName  \
# 0                 PC                Baldur's Gate 3 Early Access Review
# 1                 NS     Control: Ultimate Edition Cloud Version Review
# 2      XONE, PC, PS4       Doom Eternal: The Ancient Gods Part 1 Review
# 3      XONE, PC, PS4                          Watch Dogs: Legion Review
# 4                 PC                                Ring Of Pain Review
# ...              ...                                                ...
# 14796             PC                                     Doom II Review
# 14797             PC  Dungeon Master II: The Legend of Skullkeep Review
# 14798             PC                                    Endorfun Review
# 14799             PC                              FIFA Soccer 96 Review
# 14800             PC                               Full Throttle Review
#
#              Review  Score
# 0      Early Access      6
# 1              Good      7
# ...

# %%
sa = pd.read_csv('Games2.csv')

# %%
sa

# %%
sa.groupby(['Visa-Free Access'])['axs'].sum()

# %%
fa.loc[23]
# Out:
# Console                                              PC
# GameName    Serious Sam 4 Review – The Fourth Encounter
# Review                                             Good
# Score                                                 7
# Name: 23, dtype: object
